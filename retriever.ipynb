# %% [markdown]
# # Retriever

# %% [markdown]
# provide trading recommendations for new and unseen tickers

# %%
import pickle
import pandas as pd
import yfinance as yf # original was 0.2.4 now 0.2.11
from datetime import datetime, timedelta
import numpy as np

yf.__version__
# Out:
# '0.2.11'

# %% [markdown]
# ## load classifiers

# %%
CLFS = []
for i in range(10):
    for j in range(10):
        with open(f'../model_cls/seed_{i}_{j}.pickle','rb') as f:
            CLFS.append( pickle.loads(f.read()) )

# %% [markdown]
# ## get data

# %% [markdown]
# need to load these columns: ticker, 'eps_est',
#         'eps_actual',
#         'eps_diff',
#        'on_earnings_close',
#        'on_earnings_volume',
#        'market_cap',
#        'price_var'
#
# data assumptions: close>5, eps_diff > 0.0

# %% [markdown]
# ### load recently eps-ed tickers

# %%
ech = pd.read_csv('../earnings_calendar_history/2023-02-04.csv')
ech['ticker'] = ech['TICKER\nNO MATCHES'].map(lambda t: t.split(';')[0])
ech['eps_diff'] = ech['SURPRISE'].map(lambda s: float(s.replace('−','-').replace('USD','').replace('—','-1')))
sel_tickers = ech.loc[ech.eps_diff>0,'ticker'].to_list()
print(f"Found {len(sel_tickers)} tickers with eps diff > 0")
# Out:
# Found 107 tickers with eps diff > 0

# %%
class TickerModel():

    def __init__(self,ticker):
        self.ticker= ticker
        self.model = yf.Ticker(ticker)
        self.has_earnings = False
        self.has_history  = False
    
    def download_earnings_dates(self):
        self.ed = self.model.earnings_dates
        if self.ed.shape[0]!=0:
            self.has_earnings = True
        else:
            return
        self.ed.dropna(inplace=True)
        self.recent_ed = self.ed.head(1).index[0] # timestamp
        self.recent_eps_actual = self.ed.head(1)['Reported EPS'][0]
        self.recent_eps_est = self.ed.head(1)['EPS Estimate'][0]
        self.recent_eps_diff = self.recent_eps_actual - self.recent_eps_est
        if self.recent_eps_diff<=0:
            print("WARNING: eps diff is not positive", self.recent_eps_diff)

    def download_history(self):
        start_date = datetime.today() - timedelta(days=100)
        end_date   = datetime.today()
        try:
            self.hist=yf.download(self.ticker, start_date, end_date)
        except Exception as e:
            print("Exception: "+str(e))

        if self.hist.shape[0]>0:
            self.has_history = True
        else:
            return

    def download_balance_sheet(self): # NOT USED ANYMORE
        """
            c.ord_shares * h.close as market_cap,
            "Ordinary Shares Number"
        """
        try:
            bs = self.model\
                .balance_sheet\
                .transpose()
        except Exception as e:
            print("Error getting balance sheet:",e)
            bs = self.model\
                .balance_sheet\
                .transpose()
        bs_cols = [c for c in bs.columns if c in ['Total Assets','Common Stock','Total Capitalization','Total Debt', 'Net Debt','Ordinary Shares Number']]
        self.balance_sheet = bs[bs_cols]
        self.ord_shares = bs['Ordinary Shares Number'][0]

    def create_features(self) -> pd.DataFrame:
        ed = str(self.recent_ed)[:10]
        on_earnings_close = self.hist.loc[ed, 'Close']
        on_earnings_vol   = self.hist.loc[ed, 'Volume']
        market_cap = self.model.fast_info.market_cap
        # market_cap = on_earnings_close * self.ord_shares
        sub_hist = self.hist.loc[:ed]
        price_var = sub_hist.Close.std()/sub_hist.Close.mean()

        self.F = pd.DataFrame({
            'eps_est':self.recent_eps_est, 
            'eps_actual':self.recent_eps_actual, 
            'eps_diff':self.recent_eps_diff, 
            'on_earnings_close':on_earnings_close, 
            'on_earnings_volume':on_earnings_vol, 
            'market_cap':market_cap,
            'price_var':price_var
        }, index=[self.ticker])

        return self.F

    def predict_class(self, CLFS) -> float:
        probas = []
        for clf in CLFS:
            probas.append( clf.predict_proba(self.F)[:,1][0] )
        self.probas = probas
        self.avg_pred = np.mean(probas)

        return self.avg_pred

    def __repr__(self):
        return f"TickerModel of {self.ticker}"

TickerModels = [TickerModel(t) for t in sel_tickers]

# %%
results = {}

for i in range(len(sel_tickers)):
    print(i,len(sel_tickers),TickerModels[i])
    try:
        TickerModels[i].download_earnings_dates()
        TickerModels[i].download_history()
        # TickerModels[i].download_balance_sheet()
        TickerModels[i].create_features()
        pred = TickerModels[i].predict_class(CLFS)
    except:
        continue
    results[TickerModels[i].ticker] = pred
    print(pred)
# Out:
# 0 107 TickerModel of XOM
# [*********************100%***********************]  1 of 1 completed
# 0.31602294123330404
# 1 107 TickerModel of LLY
# [*********************100%***********************]  1 of 1 completed
# 0.28216464556893184
# 2 107 TickerModel of MRK
# [*********************100%***********************]  1 of 1 completed
# 0.34737455231852915
# 3 107 TickerModel of PFE
# [*********************100%***********************]  1 of 1 completed
# 0.44123581602427064
# 4 107 TickerModel of TMO
# [*********************100%***********************]  1 of 1 completed
# 0.4145758237055741
# 5 107 TickerModel of MCD
# [*********************100%***********************]  1 of 1 completed
# 0.25954610415168966
# 6 107 TickerModel of TMUS
# [*********************100%***********************]  1 of 1 completed
# 0.32159127069259974
# 7 107 TickerModel of UPS
# [*********************100%***********************]  1 of 1 completed
# 0.42065532532938754
# 8 107 TickerModel of BMY
# [*********************100%***********************]  1 of 1 completed
# 0.36566424538304565
# 9 107 TickerModel of QCOM
# [*********************100%***********************]  1 of 1 completed
# 0.5551933050674994
# 10 107 TickerModel of AMD
# [*********************100%***********************]  1 of 1 completed
# 0.5263135921453059
# 11 107 TickerModel of HON
# [*********************100%***********************]  1 of 1 completed
# 0.28072759343863496
# 12 107 TickerModel of SYK
# [*********************100%***********************]  1 of 1 completed
# 0.49365400667840154
# 13 107 TickerModel of GILD
# [*********************100%***********************]  1 of 1 completed
# 0.32769722171042426
# 14 107 TickerModel of EL
# 15 107 TickerModel of MDLZ
# [*********************100%***********************]  1 of 1 completed
# 0.292899179235614
# 16 107 TickerModel of CI
# [*********************100%***********************]  1 of 1 completed
# 0.43530731356048025
# 17 107 TickerModel of REGN
# [*********************100%***********************]  1 of 1 completed
# 0.4489131363938052
# 18 107 TickerModel of MO
# WARNING: eps diff is not positive 0.0
# [*********************100%***********************]  1 of 1 completed
# 0.3060584025132517
# 19 107 TickerModel of ITW
# [*********************100%***********************]  1 of 1 completed
# 0.35621526155604344
# 20 107 TickerModel of BDX
# [*********************100%***********************]  1 of 1 completed
# 0.41720860707566937
# 21 107 TickerModel of AON
# [*********************100%***********************]  1 of 1 completed
# 0.43000294554349905
# 22 107 TickerModel of HUM
# [*********************100%***********************]  1 of 1 completed
# 0.3308641047166738
# 23 107 TickerModel of MCO
# [*********************100%***********************]  1 of 1 completed
# 0.40085549573919654
# 24 107 TickerModel of SCCO
# [*********************100%***********************]  1 of 1 completed
# 0.578730096247958
# 25 107 TickerModel of GM
# [*********************100%***********************]  1 of 1 completed
# 0.5063793983066343
# 26 107 TickerModel of EPD
# [*********************100%***********************]  1 of 1 completed
# 0.39096703320738213
# 27 107 TickerModel of MPC
# [*********************100%***********************]  1 of 1 completed
# 0.5933121649756251
# 28 107 TickerModel of EW
# [*********************100%***********************]  1 of 1 completed
# 0.3669306119051162
# 29 107 TickerModel of MCK
# [*********************100%***********************]  1 of 1 completed
# 0.40168765964768804
# 30 107 TickerModel of NXPI
# [*********************100%***********************]  1 of 1 completed
# 0.49193862958952295
# 31 107 TickerModel of HSY
# [*********************100%***********************]  1 of 1 completed
# 0.34555947274077903
# 32 107 TickerModel of MCHP
# [*********************100%***********************]  1 of 1 completed
# 0.4615667907537262
# 33 107 TickerModel of MSCI
# [*********************100%***********************]  1 of 1 completed
# 0.4009214908165282
# 34 107 TickerModel of PH
# [*********************100%***********************]  1 of 1 completed
# 0.4838953398737831
# 35 107 TickerModel of CTVA
# [*********************100%***********************]  1 of 1 completed
# 0.41084599557772455
# 36 107 TickerModel of TEAM
# [*********************100%***********************]  1 of 1 completed
# 0.6037426540762797
# 37 107 TickerModel of AFL
# [*********************100%***********************]  1 of 1 completed
# 0.3357572440402032
# 38 107 TickerModel of TT
# [*********************100%***********************]  1 of 1 completed
# 0.356382863228269
# 39 107 TickerModel of ODFL
# [*********************100%***********************]  1 of 1 completed
# 0.47164150453363846
# 40 107 TickerModel of OTIS
# [*********************100%***********************]  1 of 1 completed
# 0.3908049543330656
# 41 107 TickerModel of GWW
# [*********************100%***********************]  1 of 1 completed
# 0.495738838446512
# 42 107 TickerModel of AME
# [*********************100%***********************]  1 of 1 completed
# 0.2976520049940425
# 43 107 TickerModel of LYB
# [*********************100%***********************]  1 of 1 completed
# 0.4827065570570794
# 44 107 TickerModel of ABC
# [*********************100%***********************]  1 of 1 completed
# 0.39164477130908604
# 45 107 TickerModel of EA
# WARNING: eps diff is not positive -0.25
# [*********************100%***********************]  1 of 1 completed
# 0.3982450040210918
# 46 107 TickerModel of APTV
# [*********************100%***********************]  1 of 1 completed
# 0.5212523044786316
# 47 107 TickerModel of GLW
# [*********************100%***********************]  1 of 1 completed
# 0.44603889432668736
# 48 107 TickerModel of WEC
# [*********************100%***********************]  1 of 1 completed
# 0.3280421296584583
# 49 107 TickerModel of ZBH
# [*********************100%***********************]  1 of 1 completed
# 0.4360053494428715
# 50 107 TickerModel of ALGN
# [*********************100%***********************]  1 of 1 completed
# 0.5902507717646515
# 51 107 TickerModel of FTV
# [*********************100%***********************]  1 of 1 completed
# 0.3255348108980073
# 52 107 TickerModel of HIG
# [*********************100%***********************]  1 of 1 completed
# 0.3166520616812088
# 53 107 TickerModel of PFG
# [*********************100%***********************]  1 of 1 completed
# 0.398231302946706
# 54 107 TickerModel of DOV
# [*********************100%***********************]  1 of 1 completed
# 0.4054148601795788
# 55 107 TickerModel of HOLX
# [*********************100%***********************]  1 of 1 completed
# 0.4033904165518492
# 56 107 TickerModel of SIRI
# [*********************100%***********************]  1 of 1 completed
# 0.46999344228596507
# 57 107 TickerModel of CAH
# [*********************100%***********************]  1 of 1 completed
# 0.33107452412679456
# 58 107 TickerModel of CHD
# WARNING: eps diff is not positive -1.27
# [*********************100%***********************]  1 of 1 completed
# 0.4339552058793621
# 59 107 TickerModel of MAA
# [*********************100%***********************]  1 of 1 completed
# 0.38932969027075415
# 60 107 TickerModel of CLX
# [*********************100%***********************]  1 of 1 completed
# 0.3221812221259032
# 61 107 TickerModel of LPLA
# [*********************100%***********************]  1 of 1 completed
# 0.6009181765231602
# 62 107 TickerModel of CMS
# [*********************100%***********************]  1 of 1 completed
# 0.41034488088191895
# 63 107 TickerModel of BR
# [*********************100%***********************]  1 of 1 completed
# 0.3974211272208485
# 64 107 TickerModel of MKL
# [*********************100%***********************]  1 of 1 completed
# 0.5290477130992016
# 65 107 TickerModel of IEX
# [*********************100%***********************]  1 of 1 completed
# 0.29502385974645406
# 66 107 TickerModel of UI
# [*********************100%***********************]  1 of 1 completed
# 0.37330149663932544
# 67 107 TickerModel of NVR
# [*********************100%***********************]  1 of 1 completed
# 0.6547241458386093
# 68 107 TickerModel of TW
# [*********************100%***********************]  1 of 1 completed
# 0.5635101797740218
# 69 107 TickerModel of DGX
# [*********************100%***********************]  1 of 1 completed
# 0.3512068290633225
# 70 107 TickerModel of AVTR
# [*********************100%***********************]  1 of 1 completed
# 0.5373859537065566
# 71 107 TickerModel of IP
# [*********************100%***********************]  1 of 1 completed
# 0.43282927660357695
# 72 107 TickerModel of SWK
# [*********************100%***********************]  1 of 1 completed
# 0.5157595771547168
# 73 107 TickerModel of GEN
# [*********************100%***********************]  1 of 1 completed
# 0.44205154395421487
# 74 107 TickerModel of SNA
# [*********************100%***********************]  1 of 1 completed
# 0.4752010394315576
# 75 107 TickerModel of ELS
# [*********************100%***********************]  1 of 1 completed
# 0.40076241053662587
# 76 107 TickerModel of PHM
# [*********************100%***********************]  1 of 1 completed
# 0.6522419836433646
# 77 107 TickerModel of CBOE
# [*********************100%***********************]  1 of 1 completed
# 0.28591507194970656
# 78 107 TickerModel of CPT
# [*********************100%***********************]  1 of 1 completed
# 0.3927023982547788
# 79 107 TickerModel of HUBB
# [*********************100%***********************]  1 of 1 completed
# 0.41588894343163463
# 80 107 TickerModel of PCTY
# [*********************100%***********************]  1 of 1 completed
# 0.43584035724314113
# 81 107 TickerModel of GGG
# [*********************100%***********************]  1 of 1 completed
# 0.31284314187272183
# 82 107 TickerModel of BXP
# [*********************100%***********************]  1 of 1 completed
# 0.4071656139740549
# 83 107 TickerModel of GL
# [*********************100%***********************]  1 of 1 completed
# 0.3823296888777969
# 84 107 TickerModel of AFG
# [*********************100%***********************]  1 of 1 completed
# 0.39534304177635726
# 85 107 TickerModel of DOX
# [*********************100%***********************]  1 of 1 completed
# 0.39333597328845005
# 86 107 TickerModel of DECK
# [*********************100%***********************]  1 of 1 completed
# 0.6331405604441609
# 87 107 TickerModel of QRVO
# [*********************100%***********************]  1 of 1 completed
# 0.5283078583299523
# 88 107 TickerModel of AOS
# [*********************100%***********************]  1 of 1 completed
# 0.41714081515026086
# 89 107 TickerModel of RRX
# [*********************100%***********************]  1 of 1 completed
# 0.5236617109536489
# 90 107 TickerModel of BILL
# [*********************100%***********************]  1 of 1 completed
# 0.5613653469314854
# 91 107 TickerModel of PNR
# [*********************100%***********************]  1 of 1 completed
# 0.5308171149010468
# 92 107 TickerModel of LII
# [*********************100%***********************]  1 of 1 completed
# 0.40756509744571223
# 93 107 TickerModel of MANH
# [*********************100%***********************]  1 of 1 completed
# 0.40270277912495445
# 94 107 TickerModel of RNR
# [*********************100%***********************]  1 of 1 completed
# 0.5389672417467535
# 95 107 TickerModel of UGI
# [*********************100%***********************]  1 of 1 completed
# 0.4204505363508234
# 96 107 TickerModel of WHR
# [*********************100%***********************]  1 of 1 completed
# 0.5432381006654827
# 97 107 TickerModel of LEA
# [*********************100%***********************]  1 of 1 completed
# 0.4826495625109402
# 98 107 TickerModel of DLB
# [*********************100%***********************]  1 of 1 completed
# 0.4671807364772518
# 99 107 TickerModel of TTEK
# [*********************100%***********************]  1 of 1 completed
# 0.41359231085005743
# 100 107 TickerModel of ST
# [*********************100%***********************]  1 of 1 completed
# 0.47325914163048793
# 101 107 TickerModel of ARW
# [*********************100%***********************]  1 of 1 completed
# 0.5663215610626166
# 102 107 TickerModel of ALGM
# [*********************100%***********************]  1 of 1 completed
# 0.5862742160321371
# 103 107 TickerModel of BERY
# [*********************100%***********************]  1 of 1 completed
# 0.5454890316417592
# 104 107 TickerModel of HOG
# [*********************100%***********************]  1 of 1 completed
# 0.47206292197348515
# 105 107 TickerModel of CFLT
# [*********************100%***********************]  1 of 1 completed
# 0.5865885526774139
# 106 107 TickerModel of BYD
# [*********************100%***********************]  1 of 1 completed
# 0.4245056021791925

# %%
print("tickers to consider")
for ticker, pred in results.items():
    if pred>0.6:
        print(ticker, pred)
# Out:
# tickers to consider
# TEAM 0.6037426540762797
# LPLA 0.6009181765231602
# NVR 0.6547241458386093
# PHM 0.6522419836433646
# DECK 0.6331405604441609

# %% [markdown]
# ## check ticker

# %%
TM = [m for m in TickerModels if m.ticker=='NVR'][0]

# %%
TM.ed
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2023-01-31 04:00:00-05:00         98.88        133.44       0.3495
# 2022-10-25 05:00:00-04:00        121.71        118.51      -0.0263
# 2022-07-26 05:00:00-04:00        126.77        123.65      -0.0246
# 2022-04-26 05:00:00-04:00         96.98        116.56       0.2019
# 2022-02-01 04:00:00-05:00         99.76         89.09      -0.1070
# 2021-10-21 05:00:00-04:00         92.51         86.44      -0.0656
# 2021-07-21 05:00:00-04:00         72.53         82.45       0.1368
# 2021-04-21 05:00:00-04:00         63.01         63.21       0.0032

# %%
TM.hist.tail(10)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2023-01-25 00:00:00-05:00  4990.220215  5089.000000  4990.220215  5069.060059
# 2023-01-26 00:00:00-05:00  5100.000000  5176.189941  5037.500000  5112.220215
# 2023-01-27 00:00:00-05:00  5067.819824  5149.990234  5067.819824  5122.009766
# 2023-01-30 00:00:00-05:00  5101.209961  5131.930176  5001.009766  5021.419922
# 2023-01-31 00:00:00-05:00  5199.000000  5349.990234  5151.160156  5270.000000
# 2023-02-01 00:00:00-05:00  5276.259766  5376.000000  5185.120117  5357.919922
# 2023-02-02 00:00:00-05:00  5330.509766  5500.000000  5304.279785  5405.669922
# 2023-02-03 00:00:00-05:00  5307.310059  5359.720215  5200.000000  5281.339844
# 2023-02-06 00:00:00-05:00  5245.000000  5245.000000  5116.990234  5149.439941
# 2023-02-07 00:00:00-05:00  5112.000000  5124.359863  5039.020020  5101.000000
#
#                              Adj Close  Volume
# Date
# 2023-01-25 00:00:00-05:00  5069.060059   10100
# 2023-01-26 00:00:00-05:00  5112.220215    9500
# 2023-01-27 00:00:00-05:00  5122.009766   10100
# 2023-01-30 00:00:00-05:00  5021.419922   18500
# 2023-01-31 00:00:00-05:00  5270.000000   32700
# 2023-02-01 00:00:00-05:00  5357.919922   24400
# 2023-02-02 00:00:00-05:00  5405.669922   43400
# 2023-02-03 00:00:00-05:00  5281.339844   39500
# 2023-02-06 00:00:00-05:00  5149.439941   52000
# 2023-02-07 00:00:00-05:00  5101.000000    4634

# %% [markdown]
# ## trades actual

# %% [markdown]
# 2023-02-04 NVR 65%\
# 2023-02-11 RCL 75% -10%/+10%
